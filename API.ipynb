# %% [markdown]
# API MAIN DOMAIN KEY

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '07f76328-85a5-4b3f-8122-63a6d3eed8d7',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:00:42.045Z', 'error_code': 0, 'error_message': None, 'elapsed': 33, 'credit_count': 1, 'notice': None, 'total_count': 8818}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10821, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
df=pd.json_normalize(data['data'])

# %%
df
# Out:
#        id           name symbol           slug  num_market_pairs  \
# 0       1        Bitcoin    BTC        bitcoin             10821
# 1    1027       Ethereum    ETH       ethereum              8428
# 2     825    Tether USDt   USDT         tether             74897
# 3    1839            BNB    BNB            bnb              2070
# 4    5426         Solana    SOL         solana               626
# ..    ...            ...    ...            ...               ...
# 95   7548          WEMIX  WEMIX          wemix                52
# 96   1659         Gnosis    GNO     gnosis-gno               169
# 97  13631  Manta Network  MANTA  manta-network                84
# 98   1042        Siacoin     SC        siacoin                95
# 99  17799         Axelar    AXL         axelar                82
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# ...

# %% [markdown]
# API SANDBOX URL

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '07f76328-85a5-4b3f-8122-63a6d3eed8d7',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:07:21.718Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 5637, 'name': '7vz4veojgqh', 'symbol': 'nlr6bml56xo', 'slug': '0ockigua1b1j', 'cmc_rank': 3098, 'num_market_pairs': 1733, 'circulating_supply': 152, 'total_supply': 8875, 'max_supply': 363, 'infinite_supply': None, 'last_updated': '2024-02-20T06:07:21.718Z', 'date_added': '2024-02-20T06:07:21.718Z', 'tags': ['lxykee50hir', '5e341hx3fgd', 'c05fo9m0z3j', '9zj3z6cf31', 'pskoganncm', 'mmrjfestoh8', 'tz7q9r2zvul', 'juvpyfnsrok', 'fecmjvidv8', 'wgxcgh4udp'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.28494474458439645, 'volume_24h': 4454, 'volume_change_24h': 0.5697439513941023, 'percent_change_1h': 0.958090673486929, 'percent_change_24h': 0.7190999819596207, 'percent_change_7d': 0.6136436240123593, 'market_cap': 0.3054283164416234, 'market_cap_dominance'
# ...

# %%
df1=pd.json_normalize(data['data'])

# %%
df1
# Out:
#      id         name       symbol          slug  cmc_rank  num_market_pairs  \
# 0  5637  7vz4veojgqh  nlr6bml56xo  0ockigua1b1j      3098              1733
# 1  8203   3f5qyjow2t  1txzjqbkda2   4r905u7vxxr       250              5088
# 2  1313   uafvb6rc5x   ztmd2yrx0q   ckzou6j2158      5521              6406
# 3  7744  rfsjju1pvdd   h097nekhwa   p603xqyocwn      9064              7198
# 4  2914   akfbbrjthd   q6toweqp9f   hubg08tc7wf      5555              1774
# 5  9832  58am4eyjdwc  59laxfclfac   5pg0c3skfo8      6493              8460
# 6  3630   lb2rrwnj5c   sr7ill3qw4    jyod2sdigm      8339              5204
# 7   497   56c4ybj8ho    x199bmnj9    uttnvliygz      9659              8194
# 8   434  k9w1r13yq4i   50q344daeo    j6iakylewv      1550              3005
# 9  4999  wvbjae73juf  jh4ja01v5um   ohrs9s84qnj      5036              6959
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# ...

# %% [markdown]
# accesing an API which doesn't have a APIKEY

# %%
import requests

# %%
page=requests.get('https://randomfox.ca/floof')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/9.jpg","link":"https:\/\/randomfox.ca\/?i=9"}

# %%
fox=page.json()
image=fox['image']
print(image)
# Out:
# https://randomfox.ca/images/9.jpg

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'http://api.openweathermap.org/data/2.5/forecast?id=524901&appid=260b5bc45c64414e67ff229ff9423e0a'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '8c8ca370238ba2394ec5845e7912cece',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1708419600, 'main': {'temp': 261.5, 'feels_like': 254.97, 'temp_min': 261.5, 'temp_max': 265.67, 'pressure': 1030, 'sea_level': 1030, 'grnd_level': 1010, 'humidity': 97, 'temp_kf': -4.17}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 3.59, 'deg': 187, 'gust': 6.67}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2024-02-20 09:00:00'}, {'dt': 1708430400, 'main': {'temp': 265.16, 'feels_like': 259.2, 'temp_min': 265.16, 'temp_max': 268.04, 'pressure': 1029, 'sea_level': 1029, 'grnd_level': 1009, 'humidity': 92, 'temp_kf': -2.88}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 3.83, 'deg': 180, 'gust': 7.22}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2024-02-20 12:00:00'}, {'dt': 1708441200, 'main': {'temp': 265.44, 'fee
# ...

# %%
df2=pd.json_normalize(data['list'])

# %%
df2
# Out:
#             dt                                            weather  visibility  \
# 0   1708419600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 1   1708430400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 2   1708441200  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 3   1708452000  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 4   1708462800  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 5   1708473600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 6   1708484400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 7   1708495200  [{'id': 804, 'main': 'Clouds', 'description': ...        2310
# 8   1708506000  [{'id': 600, 'main': 'Snow', 'description': 'l...         499
# 9   1708516800  [{'id': 600, 'main': 'Snow', 'description': 'l...         876
# 10  1708527600  [{'id': 600, 'main': 'Snow', 'description': 'l...         451
# ...
